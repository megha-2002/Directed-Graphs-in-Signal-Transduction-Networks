# %% [markdown]
# <a href="https://colab.research.google.com/github/megha-2002/Directed-Graphs-in-Signal-Transduction-Networks/blob/main/DirectedGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from digraph import *

# %%
#insulin

file_name=input()
size=(30,40)
signal_transduction_network(file_handle(file_name),size)
# Out:
# data1.txt

# %%
#retina
file_name=input()
size=(30,40)
signal_transduction_network(file_handle(file_name),size)
# Out:
# data2.txt

# %%
#ABA
file_name=input()
size=(30,40)
signal_transduction_network(file_handle(file_name),size)
# Out:
# data3.txt

# %%
#G-protein
file_name=input()
size=(30,40)
signal_transduction_network(file_handle(file_name),size)
# Out:
# data4.txt
